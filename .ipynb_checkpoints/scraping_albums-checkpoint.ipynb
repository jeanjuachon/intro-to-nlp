# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from bs4 import BeautifulSoup
import requests

# %%
cid ='1fee343b24a04165a0c05a14508d3929'
secret ='4ed932cb67bb4b879456cf0032d751ef'

client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
#insert the URI as a string into the function
def get_album_tracks(uri_info):
    uri = []
    track = []
    duration = []
    explicit = []
    track_number = []
    one = sp.album_tracks(uri_info, limit=50, offset=0, market='PH')
    df1 = pd.DataFrame(one)
    
    for i, x in df1['items'].items():
        uri.append(x['uri'])
        track.append(x['name'])
        duration.append(x['duration_ms'])
        explicit.append(x['explicit'])
        track_number.append(x['track_number'])
    
    df2 = pd.DataFrame({
    'uri':uri,
    'track':track,
    'duration_ms':duration,
    'explicit':explicit,
    'track_number':track_number})
    
    return df2

# %%
#insert output dataframe from the get_album_tracks function
def get_track_info(df):
    danceability = []
    energy = []
    key = []
    loudness = []
    speechiness = []
    acousticness = []
    instrumentalness = []
    liveness = []
    valence = []
    tempo = []
    for i in df['uri']:
        for x in sp.audio_features(tracks=[i]):
            danceability.append(x['danceability'])
            energy.append(x['energy'])
            key.append(x['key'])
            loudness.append(x['loudness'])
            speechiness.append(x['speechiness'])
            acousticness.append(x['acousticness'])
            instrumentalness.append(x['instrumentalness'])
            liveness.append(x['liveness'])
            valence.append(x['valence'])
            tempo.append(x['tempo'])
            
    df2 = pd.DataFrame({
    'danceability':danceability,
    'energy':energy,
    'key':key,
    'loudness':loudness,
    'speechiness':speechiness,
    'acousticness':acousticness,
    'instrumentalness':instrumentalness,
    'liveness':liveness,
    'valence':valence,
    'tempo':tempo})
    
    return df2

# %%
def merge_frames(df1, df2):
    df3 = df1.merge(df2, left_index= True, right_index= True)
    return df3

# %%
#function to scrape lyrics from genius
def scrape_lyrics(artistname, songname):
    artistname2 = str(artistname.replace(' ','-')) if ' ' in artistname else str(artistname)
    songname2 = str(songname.replace(' ','-')) if ' ' in songname else str(songname)
    page = requests.get('https://genius.com/'+ artistname2 + '-' + songname2 + '-' + 'lyrics')
    html = BeautifulSoup(page.text, 'html.parser')
    lyrics1 = html.find("div", class_="lyrics")
    lyrics2 = html.find("div", class_="Lyrics__Container-sc-1ynbvzw-2 jgQsqn")
    if lyrics1:
        lyrics = lyrics1.get_text()
    elif lyrics2:
        lyrics = lyrics2.get_text()
    elif lyrics1 == lyrics2 == None:
        lyrics = None
    return lyrics

#function to attach lyrics onto data frame
#artist_name should be inserted as a string
def lyrics_onto_frame(df1, artist_name):
    for i,x in enumerate(df1['track']):
        test = scrape_lyrics(artist_name, x)
        df1.loc[i, 'lyrics'] = test
    return df1

# %%
df1 = get_album_tracks("https://open.spotify.com/album/0HYAcVSUVkfxzHKgHu6DqR?si=8_P8UJEhRjuhH3_alb_UkQ&dl_branch=1")

# %%
df1
# Out:
#                                      uri                    track  \
# 0   spotify:track:0SzvXb3BAWgTHACbIXGNPa                    Halik
# 1   spotify:track:4i7MM02jQaGM647D6AYxGQ                 T. N. T.
# 2   spotify:track:4xAhwyWKlfDVk7VmAcU0dG                    Tamis
# 3   spotify:track:2scfoYmaEbyFnSTezCxRXZ                  Tagpuan
# 4   spotify:track:3DXxVdbUD19DXaEUNeV9iH     Sana'y Laging Ganito
# 5   spotify:track:53G6pMNfG3Rs6AmjXEFi2D          Sobrang Lungkot
# 6   spotify:track:0QmznEuGS0D7Idty5K621P                   Kislap
# 7   spotify:track:6c9U3GAtEf8foe4wivGHBU                    Wo-Oh
# 8   spotify:track:2wNHeyneZ33m9SgGnF0jGS       If You're Not Here
# 9   spotify:track:4IN4byZRGdMBHaGkKbrcaE                    Paano
# 10  spotify:track:7L8GQLm6e7cGoMMUAgWCVp             Huling Sayaw
# 11  spotify:track:4Qr1VnEEWGsDnmdiU2P8Nu         Halik - Acoustic
# 12  spotify:track:0htrzzNuPJ5odJd92yD93g       Tagpuan - Acoustic
# 13  spotify:track:4UgtdWy4dm7vMVIupUbtMm  Huling Sayaw - Acoustic
#
#     duration_ms  explicit  track_number
# 0        222680     False             1
# 1         99320     False             2
# 2        225040     False             3
# 3        255453     False             4
# 4        212493     False             5
# 5         20346     False             6
# 6        223213     False             7
# 7        187813     False             8
# 8        266706     False             9
# 9        267240     False            10
# 10       295413     False            11
# 11       238253     False            12
# 12       258773     False            13
# 13       260253     False            14

# %%
# clara_tracks_meta = get_track_info(clara_tracks)

# %%
# clara_tracks_meta
# Out:
#     danceability  energy  key  loudness  speechiness  acousticness  \
# 0          0.525   0.908   11    -3.330       0.0413      0.013900
# 1          0.558   0.963   11    -3.337       0.1450      0.013100
# 2          0.492   0.742    7    -4.241       0.0330      0.009690
# 3          0.441   0.875    2    -3.294       0.0366      0.000781
# 4          0.530   0.868    2    -3.594       0.0359      0.000703
# 5          0.806   0.312    0    -7.317       0.2510      0.254000
# 6          0.543   0.938    0    -3.549       0.0653      0.000433
# 7          0.311   0.920    9    -3.394       0.0558      0.009970
# 8          0.286   0.955    2    -3.460       0.1260      0.000179
# 9          0.396   0.883    4    -3.473       0.0749      0.000179
# 10         0.474   0.871    1    -4.013       0.0405      0.001250
# 11         0.679   0.688   11    -5.138       0.0333      0.420000
# 12         0.628   0.515    2    -7.514       0.0279      0.715000
# 13         0.611   0.308    4    -7.999       0.0272      0.865000
#
#     instrumentalness  liveness  valence    tempo
# 0           0.000000    0.2530    0.628  126.041
# 1           0.000000    0.7770    0.648  135.059
# 2           0.000009    0.1180    0.738  145.123
# 3           0.000000    0.3830    0.622  138.030
# 4           0.000000    0.3550    0.624   93.580
# 5           0.156000    0.3360    0.111  111.276
# 6           0.000027    0.0572    0.658  109.984
# 7           0.000000    0.3280    0.644   94.946
# 8           0.000932    0.4440    0.382  149.650
# 9           0.000001    0.1560    0.490  166.090
# 10          0.000000    0.2020    0.545  137.102
# 11          0.000000    0.1840    0.354  115.072
# 12          0.000000    0.3340    0.394  138.091
# 13          0.000000    0.1250    0.315  135.015

# %%
df1 = merge_frames(clara_tracks, clara_tracks_meta)

# %%
df1.head()
# Out:
#                                     uri                 track  duration_ms  \
# 0  spotify:track:0SzvXb3BAWgTHACbIXGNPa                 Halik       222680
# 1  spotify:track:4i7MM02jQaGM647D6AYxGQ              T. N. T.        99320
# 2  spotify:track:4xAhwyWKlfDVk7VmAcU0dG                 Tamis       225040
# 3  spotify:track:2scfoYmaEbyFnSTezCxRXZ               Tagpuan       255453
# 4  spotify:track:3DXxVdbUD19DXaEUNeV9iH  Sana'y Laging Ganito       212493
#
#    explicit  track_number  danceability  energy  key  loudness  speechiness  \
# 0     False             1         0.525   0.908   11    -3.330       0.0413
# 1     False             2         0.558   0.963   11    -3.337       0.1450
# 2     False             3         0.492   0.742    7    -4.241       0.0330
# 3     False             4         0.441   0.875    2    -3.294       0.0366
# 4     False             5         0.530   0.868    2    -3.594       0.0359
#
#    acousticness  instrumentalness  liveness  valence    tempo
# 0      0.013900          0.000000     0.253    0.628  126.041
# 1      0.013100          0.000000     0.777    0.648  135.059
# 2      0.009690          0.000009     0.118    0.738  145.123
# 3      0.000781          0.000000     0.383    0.622  138.030
# 4      0.000703          0.000000     0.355    0.624   93.580

# %%
df2 = lyrics_onto_frame(df1, 'Kamikazee')

# %%
df2
# Out:
#                                      uri                    track  \
# 0   spotify:track:0SzvXb3BAWgTHACbIXGNPa                    Halik
# 1   spotify:track:4i7MM02jQaGM647D6AYxGQ                 T. N. T.
# 2   spotify:track:4xAhwyWKlfDVk7VmAcU0dG                    Tamis
# 3   spotify:track:2scfoYmaEbyFnSTezCxRXZ                  Tagpuan
# 4   spotify:track:3DXxVdbUD19DXaEUNeV9iH     Sana'y Laging Ganito
# 5   spotify:track:53G6pMNfG3Rs6AmjXEFi2D          Sobrang Lungkot
# 6   spotify:track:0QmznEuGS0D7Idty5K621P                   Kislap
# 7   spotify:track:6c9U3GAtEf8foe4wivGHBU                    Wo-Oh
# 8   spotify:track:2wNHeyneZ33m9SgGnF0jGS       If You're Not Here
# 9   spotify:track:4IN4byZRGdMBHaGkKbrcaE                    Paano
# 10  spotify:track:7L8GQLm6e7cGoMMUAgWCVp             Huling Sayaw
# 11  spotify:track:4Qr1VnEEWGsDnmdiU2P8Nu         Halik - Acoustic
# 12  spotify:track:0htrzzNuPJ5odJd92yD93g       Tagpuan - Acoustic
# 13  spotify:track:4UgtdWy4dm7vMVIupUbtMm  Huling Sayaw - Acoustic
#
#     duration_ms  explicit  track_number  danceability  energy  key  loudness  \
# 0        222680     False             1         0.525   0.908   11    -3.330
# 1         99320     False             2         0.558   0.963   11    -3.337
# 2        225040     False             3         0.492   0.742    7    -4.241
# 3        255453     False             4         0.441   0.875    2    -3.294
# 4        212493     False             5         0.530   0.868    2    -3.594
# 5         20346     False             6         0.806   0.312    0    -7.317
# 6        223213     False             7         0.543   0.938    0    -3.549
# 7        187813     False             8         0.311   0.920    9    -3.394
# 8        266706     False             9         0.286   0.955    2    -3.460
# 9        267240     False            10         0.396   0.883    4    -3.473
# 10       295413     False            11         0.474   0.871    1    -4.013
# 11       238253     False            12         0.679   0.688   11    -5.138
# 12       258773     False            13         0.628   0.515    2    -7.514
# 13       260253     False            14         0.611   0.308    4    -7.999
#
#     speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0        0.0413      0.013900          0.000000    0.2530    0.628  126.041
# 1        0.1450      0.013100          0.000000    0.7770    0.648  135.059
# 2        0.0330      0.009690          0.000009    0.1180    0.738  145.123
# 3        0.0366      0.000781          0.000000    0.3830    0.622  138.030
# 4        0.0359      0.000703          0.000000    0.3550    0.624   93.580
# 5        0.2510      0.254000          0.156000    0.3360    0.111  111.276
# 6        0.0653      0.000433          0.000027    0.0572    0.658  109.984
# 7        0.0558      0.009970          0.000000    0.3280    0.644   94.946
# 8        0.1260      0.000179          0.000932    0.4440    0.382  149.650
# 9        0.0749      0.000179          0.000001    0.1560    0.490  166.090
# 10       0.0405      0.001250          0.000000    0.2020    0.545  137.102
# 11       0.0333      0.420000          0.000000    0.1840    0.354  115.072
# 12       0.0279      0.715000          0.000000    0.3340    0.394  138.091
# 13       0.0272      0.865000          0.000000    0.1250    0.315  135.015
#
#                                                lyrics
# 0                                                 NaN
# 1                                                 NaN
# 2   \n\nNahuli na ang kiliti\nDating kaba naging k...
# 3   \n\n[Verse 1]\nNagbibilang ng sandali\nPintig ...
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None

# %%
#function to scrape lyrics from genius
def scrape_lyrics(artistname, songname):
    artistname2 = str(artistname.replace(' ','-')) if ' ' in artistname else str(artistname)
    songname2 = str(songname.replace(' ','-')) if ' ' in songname else str(songname)
    page = requests.get('https://genius.com/'+ artistname2 + '-' + songname2 + '-' + 'lyrics')
    html = BeautifulSoup(page.text, 'html.parser')
    lyrics1 = html.find("div", class_="lyrics")
    lyrics2 = html.find("div", class_="Lyrics__Container-sc-1ynbvzw-2 jgQsqn")
    if lyrics1:
        lyrics = lyrics1.get_text()
    elif lyrics2:
        lyrics = lyrics2.get_text()
    elif lyrics1 == lyrics2 == None:
        lyrics = None
    return lyrics

#function to attach lyrics onto data frame
#artist_name should be inserted as a string
def lyrics_onto_frame(df1, artist_name):
    for i,x in enumerate(df1['track']):
        test = scrape_lyrics(artist_name, x)
        df1.loc[i, 'lyrics'] = test
    return df1
